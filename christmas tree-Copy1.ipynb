# %%
import turtle

t = turtle.Turtle()
turtle.bgcolor("black")
t.speed(0)
t.penup()
t.fillcolor("gold")
t.begin_fill()
t.circle(8,steps = 4)
t.end_fill()

t.fillcolor("springgreen4")
t.begin_fill()
t.circle(-110,steps = 3)
t.end_fill()




t.penup()
t.setpos(-90,-170)
t.pendown()
t.pencolor("gold")
t.fillcolor("gold")
t.begin_fill()
for a in range(1):
    t.circle(5)
t.end_fill() 

t.penup()
t.setpos(-70,-170)
t.pendown()

t.fillcolor("gold")
t.begin_fill()
for a in range(1):
    t.circle(5)
t.end_fill() 
t.penup()
t.setpos(-50,-170)
t.pendown()

t.fillcolor("gold")
t.begin_fill()
for a in range(1):
    t.circle(5)
t.end_fill()
t.penup()
t.setpos(-30,-170)
t.pendown()

t.fillcolor("gold")
t.begin_fill()
for a in range(1):
    t.circle(5)
t.end_fill()


t.penup()
t.setpos(30,-170)
t.pendown()
t.fillcolor("gold")
t.begin_fill()
for a in range(1):
    t.circle(5)
t.end_fill()

t.penup()
t.setpos(50,-170)
t.pendown()
t.fillcolor("gold")
t.begin_fill()
for a in range(1):
    t.circle(5)
t.end_fill()


t.penup()
t.setpos(70,-170)
t.pendown()
t.fillcolor("gold")
t.begin_fill()
for a in range(1):
    t.circle(5)
t.end_fill()

t.penup()
t.setpos(90,-170)
t.pendown()
t.fillcolor("gold")
t.begin_fill()
for a in range(1):
    t.circle(5)
t.end_fill()



t.pencolor("red")
t.penup()
t.setpos(-60,-110)
t.pendown()
t.fillcolor("red")
t.begin_fill()
for a in range(1):
    t.circle(5)
t.end_fill()



t.penup()
t.setpos(-40,-110)
t.pendown()
t.fillcolor("red")
t.begin_fill()
for a in range(1):
    t.circle(5)
t.end_fill()

t.penup()
t.setpos(-20,-110)
t.pendown()
t.fillcolor("red")
t.begin_fill()
for a in range(1):
    t.circle(5)
t.end_fill()

t.penup()
t.setpos(0,-110)
t.pendown()
t.fillcolor("red")
t.begin_fill()
for a in range(1):
    t.circle(5)
t.end_fill()


t.penup()
t.setpos(20,-110)
t.pendown()
t.fillcolor("red")
t.begin_fill()
for a in range(1):
    t.circle(5)
t.end_fill()

t.penup()
t.setpos(40,-110)
t.pendown()
t.fillcolor("red")
t.begin_fill()
for a in range(1):
    t.circle(5)
t.end_fill()

t.penup()
t.setpos(60,-110)
t.pendown()
t.fillcolor("red")
t.begin_fill()
for a in range(1):
    t.circle(5)
t.end_fill()


t.penup()
t.setpos(-30,-50)
t.pendown()
t.pencolor("gold")
t.fillcolor("gold")
t.begin_fill()
for a in range(1):
    t.circle(5)
t.end_fill() 


t.penup()
t.setpos(-10,-50)
t.pendown()
t.pencolor("gold")
t.fillcolor("gold")
t.begin_fill()
for a in range(1):
    t.circle(5)
t.end_fill() 


t.penup()
t.setpos(10,-50)
t.pendown()
t.pencolor("gold")
t.fillcolor("gold")
t.begin_fill()
for a in range(1):
    t.circle(5)
t.end_fill() 

t.penup()
t.setpos(30,-50)
t.pendown()
t.pencolor("gold")
t.fillcolor("gold")
t.begin_fill()
for a in range(1):
    t.circle(5)
t.end_fill() 
t.pendown()
def draw_rectangle(t,x,y,width,height,color):
  t.pencolor("brown")
  
  t.begin_fill()
  t.fillcolor(color)
  
  t.setheading(0)
 
  t.up()
  t.goto(x,y)
  t.down()
  
  t.forward(width)
  
  t.right(90)
  t.forward(height)
  
  t.right(90)
  t.forward(width)
  
  t.right(90)
  t.forward(height)
  
  t.end_fill()
 
 

draw_rectangle(t,-10,-165,20,60,"brown")




t.pencolor("gold")
t.penup()
t.setpos(-8,-165)
t.fillcolor("gold")
t.begin_fill()
for a in range(1):
    t.circle(5)
t.end_fill()

t.penup()
t.setpos(12,-165)
t.fillcolor("gold")
t.begin_fill()
for a in range(1):
    t.circle(5)
t.end_fill()


t.penup()
t.setpos(-300,100)
t.pendown()
t.speed(10)
t.color("cyan")
t.write("MERRY CHRISTMAS" ,font = ("Times New Roman",50))
